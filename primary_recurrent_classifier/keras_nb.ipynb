# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# %%
# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = '../data/keras_training/train'
validation_data_dir = '../data/keras_training/validation'
nb_train_samples = 254
nb_validation_samples = 80
epochs = 100
batch_size = 16

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 254 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/100
# C:\Users\sathy\AppData\Local\Temp\ipykernel_3768\282376359.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 15/15 [==============================] - 2s 135ms/step - loss: 0.2544 - accuracy: 0.8613 - val_loss: 13.1050 - val_accuracy: 0.8500
# Epoch 2/100
# 15/15 [==============================] - 2s 134ms/step - loss: 0.2987 - accuracy: 0.8739 - val_loss: 10.0125 - val_accuracy: 0.8250
# Epoch 3/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.2720 - accuracy: 0.8445 - val_loss: 7.7550 - val_accuracy: 0.8500
# Epoch 4/100
# 15/15 [==============================] - 2s 129ms/step - loss: 0.3032 - accuracy: 0.8235 - val_loss: 5.0834 - val_accuracy: 0.7750
# Epoch 5/100
# 15/15 [==============================] - 2s 130ms/step - loss: 0.2508 - accuracy: 0.8571 - val_loss: 5.3379 - val_accuracy: 0.8500
# Epoch 6/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2422 - accuracy: 0.8529 - val_loss: 5.7321 - val_accuracy: 0.8500
# Epoch 7/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.2979 - accuracy: 0.8445 - val_loss: 4.2680 - val_accuracy: 0.8500
# Epoch 8/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2389 - accuracy: 0.8571 - val_loss: 9.7821 - val_accuracy: 0.8500
# Epoch 9/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3268 - accuracy: 0.8583 - val_loss: 5.6365 - val_accuracy: 0.8500
# Epoch 10/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2481 - accuracy: 0.8529 - val_loss: 5.5272 - val_accuracy: 0.8500
# Epoch 11/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2175 - accuracy: 0.8908 - val_loss: 7.5248 - val_accuracy: 0.8125
# Epoch 12/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.3105 - accuracy: 0.8697 - val_loss: 6.5232 - val_accuracy: 0.8375
# Epoch 13/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2976 - accuracy: 0.8613 - val_loss: 2.9422 - val_accuracy: 0.8375
# Epoch 14/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3173 - accuracy: 0.8417 - val_loss: 2.2935 - val_accuracy: 0.8375
# Epoch 15/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2542 - accuracy: 0.8445 - val_loss: 4.0860 - val_accuracy: 0.8500
# Epoch 16/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2341 - accuracy: 0.8655 - val_loss: 4.7409 - val_accuracy: 0.8500
# Epoch 17/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.4286 - accuracy: 0.8529 - val_loss: 6.6081 - val_accuracy: 0.8500
# Epoch 18/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2591 - accuracy: 0.8487 - val_loss: 6.7971 - val_accuracy: 0.8500
# Epoch 19/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2287 - accuracy: 0.8824 - val_loss: 8.3067 - val_accuracy: 0.8500
# Epoch 20/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2423 - accuracy: 0.8571 - val_loss: 8.8936 - val_accuracy: 0.8375
# Epoch 21/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3415 - accuracy: 0.8487 - val_loss: 7.7988 - val_accuracy: 0.8500
# Epoch 22/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2458 - accuracy: 0.8739 - val_loss: 5.4716 - val_accuracy: 0.8500
# Epoch 23/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2329 - accuracy: 0.8613 - val_loss: 6.3251 - val_accuracy: 0.8500
# Epoch 24/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2447 - accuracy: 0.8571 - val_loss: 7.8814 - val_accuracy: 0.8500
# Epoch 25/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3366 - accuracy: 0.8500 - val_loss: 7.2063 - val_accuracy: 0.8500
# Epoch 26/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2346 - accuracy: 0.8739 - val_loss: 9.3792 - val_accuracy: 0.8250
# Epoch 27/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2442 - accuracy: 0.8613 - val_loss: 7.9421 - val_accuracy: 0.8500
# Epoch 28/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2560 - accuracy: 0.8613 - val_loss: 19.3853 - val_accuracy: 0.7875
# Epoch 29/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2969 - accuracy: 0.8487 - val_loss: 15.3129 - val_accuracy: 0.8500
# Epoch 30/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2768 - accuracy: 0.8655 - val_loss: 6.1572 - val_accuracy: 0.8500
# Epoch 31/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3223 - accuracy: 0.8403 - val_loss: 6.6001 - val_accuracy: 0.8375
# Epoch 32/100
# 15/15 [==============================] - 2s 133ms/step - loss: 0.2444 - accuracy: 0.8613 - val_loss: 10.0396 - val_accuracy: 0.8000
# Epoch 33/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2549 - accuracy: 0.8458 - val_loss: 18.6554 - val_accuracy: 0.8250
# Epoch 34/100
# 15/15 [==============================] - 2s 133ms/step - loss: 0.2621 - accuracy: 0.8625 - val_loss: 7.0913 - val_accuracy: 0.8500
# Epoch 35/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2258 - accuracy: 0.8782 - val_loss: 11.4290 - val_accuracy: 0.8375
# Epoch 36/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2761 - accuracy: 0.8529 - val_loss: 11.5995 - val_accuracy: 0.8500
# Epoch 37/100
# 15/15 [==============================] - 2s 127ms/step - loss: 2.4312 - accuracy: 0.8403 - val_loss: 12.8953 - val_accuracy: 0.8500
# Epoch 38/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2433 - accuracy: 0.8571 - val_loss: 12.7477 - val_accuracy: 0.8500
# Epoch 39/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3235 - accuracy: 0.8708 - val_loss: 7.6777 - val_accuracy: 0.8500
# Epoch 40/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2415 - accuracy: 0.8655 - val_loss: 8.3696 - val_accuracy: 0.8500
# Epoch 41/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.2457 - accuracy: 0.8529 - val_loss: 7.8465 - val_accuracy: 0.8500
# Epoch 42/100
# 15/15 [==============================] - 2s 119ms/step - loss: 0.2447 - accuracy: 0.8571 - val_loss: 10.1024 - val_accuracy: 0.8500
# Epoch 43/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2710 - accuracy: 0.8655 - val_loss: 5.8520 - val_accuracy: 0.8500
# Epoch 44/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2504 - accuracy: 0.8403 - val_loss: 6.2970 - val_accuracy: 0.8500
# Epoch 45/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2501 - accuracy: 0.8529 - val_loss: 6.8748 - val_accuracy: 0.8500
# Epoch 46/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2410 - accuracy: 0.8571 - val_loss: 9.7125 - val_accuracy: 0.8500
# Epoch 47/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2676 - accuracy: 0.8655 - val_loss: 14.1502 - val_accuracy: 0.8500
# Epoch 48/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2886 - accuracy: 0.8655 - val_loss: 7.0516 - val_accuracy: 0.8500
# Epoch 49/100
# 15/15 [==============================] - 2s 132ms/step - loss: 0.2477 - accuracy: 0.8487 - val_loss: 11.9963 - val_accuracy: 0.8500
# Epoch 50/100
# 15/15 [==============================] - 2s 116ms/step - loss: 0.2340 - accuracy: 0.8613 - val_loss: 14.8574 - val_accuracy: 0.8500
# Epoch 51/100
# 15/15 [==============================] - 2s 119ms/step - loss: 0.7138 - accuracy: 0.8613 - val_loss: 16.0212 - val_accuracy: 0.8500
# Epoch 52/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2420 - accuracy: 0.8613 - val_loss: 15.1529 - val_accuracy: 0.8500
# Epoch 53/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2764 - accuracy: 0.8950 - val_loss: 13.0912 - val_accuracy: 0.8375
# Epoch 54/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3023 - accuracy: 0.8529 - val_loss: 8.7044 - val_accuracy: 0.8375
# Epoch 55/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2501 - accuracy: 0.8529 - val_loss: 8.9461 - val_accuracy: 0.8500
# Epoch 56/100
# 15/15 [==============================] - 2s 120ms/step - loss: 0.2395 - accuracy: 0.8613 - val_loss: 9.9415 - val_accuracy: 0.8500
# Epoch 57/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2429 - accuracy: 0.8571 - val_loss: 14.6748 - val_accuracy: 0.8500
# Epoch 58/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2911 - accuracy: 0.8487 - val_loss: 17.8594 - val_accuracy: 0.8500
# Epoch 59/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2994 - accuracy: 0.8571 - val_loss: 8.6925 - val_accuracy: 0.8375
# Epoch 60/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2530 - accuracy: 0.8487 - val_loss: 13.5049 - val_accuracy: 0.8500
# Epoch 61/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2818 - accuracy: 0.8739 - val_loss: 12.2482 - val_accuracy: 0.8375
# Epoch 62/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2516 - accuracy: 0.8739 - val_loss: 13.9068 - val_accuracy: 0.8500
# Epoch 63/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2633 - accuracy: 0.8542 - val_loss: 9.6392 - val_accuracy: 0.8500
# Epoch 64/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2359 - accuracy: 0.8782 - val_loss: 10.6492 - val_accuracy: 0.8500
# Epoch 65/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2284 - accuracy: 0.8782 - val_loss: 12.4478 - val_accuracy: 0.8250
# Epoch 66/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2552 - accuracy: 0.8445 - val_loss: 12.7948 - val_accuracy: 0.8500
# Epoch 67/100
# 15/15 [==============================] - 2s 119ms/step - loss: 0.2553 - accuracy: 0.8529 - val_loss: 14.6942 - val_accuracy: 0.8375
# Epoch 68/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2388 - accuracy: 0.8529 - val_loss: 11.4850 - val_accuracy: 0.8500
# Epoch 69/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2394 - accuracy: 0.8655 - val_loss: 8.1282 - val_accuracy: 0.8375
# Epoch 70/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2665 - accuracy: 0.8613 - val_loss: 10.8415 - val_accuracy: 0.8250
# Epoch 71/100
# 15/15 [==============================] - 2s 119ms/step - loss: 0.2475 - accuracy: 0.8529 - val_loss: 8.4580 - val_accuracy: 0.8500
# Epoch 72/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.2371 - accuracy: 0.8571 - val_loss: 10.1348 - val_accuracy: 0.8250
# Epoch 73/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.4003 - accuracy: 0.8655 - val_loss: 12.6319 - val_accuracy: 0.8500
# Epoch 74/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.5891 - accuracy: 0.8697 - val_loss: 11.9752 - val_accuracy: 0.8250
# Epoch 75/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.2920 - accuracy: 0.8319 - val_loss: 7.8590 - val_accuracy: 0.8500
# Epoch 76/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2544 - accuracy: 0.8487 - val_loss: 7.8657 - val_accuracy: 0.8375
# Epoch 77/100
# 15/15 [==============================] - 2s 118ms/step - loss: 0.3662 - accuracy: 0.8403 - val_loss: 9.1951 - val_accuracy: 0.8375
# Epoch 78/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2310 - accuracy: 0.8655 - val_loss: 9.6938 - val_accuracy: 0.8375
# Epoch 79/100
# 15/15 [==============================] - 2s 130ms/step - loss: 0.2418 - accuracy: 0.8571 - val_loss: 7.4653 - val_accuracy: 0.8500
# Epoch 80/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.2473 - accuracy: 0.8571 - val_loss: 74.4694 - val_accuracy: 0.7750
# Epoch 81/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.0316 - accuracy: 0.8613 - val_loss: 10.0359 - val_accuracy: 0.8500
# Epoch 82/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.2402 - accuracy: 0.8571 - val_loss: 9.3460 - val_accuracy: 0.8500
# Epoch 83/100
# 15/15 [==============================] - 2s 120ms/step - loss: 0.2403 - accuracy: 0.8529 - val_loss: 8.2266 - val_accuracy: 0.8500
# Epoch 84/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2612 - accuracy: 0.8655 - val_loss: 8.6292 - val_accuracy: 0.8500
# Epoch 85/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.2538 - accuracy: 0.8529 - val_loss: 20.0451 - val_accuracy: 0.8500
# Epoch 86/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2778 - accuracy: 0.8487 - val_loss: 8.2465 - val_accuracy: 0.8500
# Epoch 87/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2581 - accuracy: 0.8487 - val_loss: 9.2225 - val_accuracy: 0.8375
# Epoch 88/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2702 - accuracy: 0.8571 - val_loss: 10.6022 - val_accuracy: 0.8500
# Epoch 89/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2370 - accuracy: 0.8583 - val_loss: 12.4319 - val_accuracy: 0.8500
# Epoch 90/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2262 - accuracy: 0.8782 - val_loss: 12.7880 - val_accuracy: 0.8500
# Epoch 91/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.6605 - accuracy: 0.8739 - val_loss: 15.6315 - val_accuracy: 0.8375
# Epoch 92/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2371 - accuracy: 0.8739 - val_loss: 42.4087 - val_accuracy: 0.7750
# Epoch 93/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3406 - accuracy: 0.8824 - val_loss: 8.1468 - val_accuracy: 0.8500
# Epoch 94/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2468 - accuracy: 0.8529 - val_loss: 7.6847 - val_accuracy: 0.8500
# Epoch 95/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2374 - accuracy: 0.8613 - val_loss: 8.5871 - val_accuracy: 0.8500
# Epoch 96/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.5903 - accuracy: 0.8361 - val_loss: 9.4474 - val_accuracy: 0.8500
# Epoch 97/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2431 - accuracy: 0.8613 - val_loss: 9.9648 - val_accuracy: 0.8500
# Epoch 98/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2382 - accuracy: 0.8655 - val_loss: 12.0954 - val_accuracy: 0.8500
# Epoch 99/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.2391 - accuracy: 0.8613 - val_loss: 10.5530 - val_accuracy: 0.8500
# Epoch 100/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.2436 - accuracy: 0.8571 - val_loss: 19.7698 - val_accuracy: 0.8500

# %%
model.save_weights('keras_vanilla.h5')

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras

# Define a simple sequential model
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(optimizer='adam',
                loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=[tf.metrics.SparseCategoricalAccuracy()])

    return model

# Create a basic model instance
model = create_model()

# Display the model's architecture
model.summary()

# Restore the weights
model.load_weights('keras_vanilla.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 32)      896
#
#  activation_10 (Activation)  (None, 148, 148, 32)      0
#
#  max_pooling2d_6 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_11 (Activation)  (None, 72, 72, 32)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 34, 34, 64)        18496
#
#  activation_12 (Activation)  (None, 34, 34, 64)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 18496)             0
#
#  dense_8 (Dense)             (None, 64)                1183808
#
#  activation_13 (Activation)  (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
#  activation_14 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 254 files belonging to 2 classes.
# Using 204 files for training.

# %%
import numpy as np
img = tf.keras.utils.load_img(
    '../data/uab_data/keras/primary/CoreID74.jpg', target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])

class_names = train_ds.class_names

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# This image most likely belongs to primary with a 65.17 percent confidence.
