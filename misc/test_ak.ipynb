# %%
from pyDeepInsight import ImageTransformer, LogScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model

import autokeras as ak
import keras as k

X = pd.read_excel('../data/tables/X_trainGBM.xlsx', sheet_name=0, header=0, names=None, index_col=0, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, decimal='.', comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)
df_tr = X.transpose()
Y = pd.read_excel('../data/tables/Y_trainGBM.xlsx', sheet_name=0, header=0, names=None, index_col=0)
print(df_tr.head())
# Out:
# TargetName                               ATP7B       ERN1      KRT74  \
# TMA 27 R1 | 001 | Geometric Segment  49.983944  60.775932  31.239965
# TMA 27 R1 | 002 | Geometric Segment  46.519148  49.501144  34.591161
# TMA 27 R1 | 003 | Geometric Segment  51.213741  42.021531  26.920043
# TMA 27 R1 | 004 | Geometric Segment  45.655397  50.591115  44.421467
# TMA 27 R1 | 005 | Geometric Segment  60.557470  49.547021  39.637617
#
# TargetName                             SPECC1L      FOXJ1     OR4K15  \
# TMA 27 R1 | 001 | Geometric Segment  46.007948  45.439949  58.503934
# TMA 27 R1 | 002 | Geometric Segment  47.115547  54.272339  58.447134
# TMA 27 R1 | 003 | Geometric Segment  43.991290  55.153259  51.870327
# TMA 27 R1 | 004 | Geometric Segment  33.316100  59.228623  53.058975
# TMA 27 R1 | 005 | Geometric Segment  45.142841  67.163740  56.153291
#
# TargetName                                 PDC      MUC15   C1orf189  \
# TMA 27 R1 | 001 | Geometric Segment  40.327955  24.991972  58.503934
# TMA 27 R1 | 002 | Geometric Segment  40.555154  22.066775  48.904745
# TMA 27 R1 | 003 | Geometric Segment  38.082012  25.606870  45.304463
# TMA 27 R1 | 004 | Geometric Segment  50.591115  28.380382  49.357186
# TMA 27 R1 | 005 | Geometric Segment  48.445976  27.526123  37.435527
#
# TargetName                                 ZXDC  ...       EIF3F       MAT2A  \
# TMA 27 R1 | 001 | Geometric Segment   98.263889  ...  206.183768  163.015817
# TMA 27 R1 | 002 | Geometric Segment   99.002289  ...  209.336164  171.763007
# TMA 27 R1 | 003 | Geometric Segment  102.427481  ...  225.209141  212.733999
# TMA 27 R1 | 004 | Geometric Segment   80.205427  ...  220.873407  146.837628
# TMA 27 R1 | 005 | Geometric Segment   89.184638  ...  188.278680  140.933749
#
# TargetName                              C2CD4C       M1AP       IQCD  \
# TMA 27 R1 | 001 | Geometric Segment  29.535967  34.647961  36.919958
# TMA 27 R1 | 002 | Geometric Segment  33.994762  29.223567  33.994762
# TMA 27 R1 | 003 | Geometric Segment  27.576630  30.202975  31.516148
# TMA 27 R1 | 004 | Geometric Segment  22.210734  24.678593  29.614311
# TMA 27 R1 | 005 | Geometric Segment  39.637617  28.627168  33.031347
#
# TargetName                               OR2H1    C1QTNF3      RAB42  \
# TMA 27 R1 | 001 | Geometric Segment  31.807964  44.303950  53.391940
# TMA 27 R1 | 002 | Geometric Segment  29.819966  36.380359  53.079540
# TMA 27 R1 | 003 | Geometric Segment  32.172734  46.617636  40.051771
# TMA 27 R1 | 004 | Geometric Segment  25.912523  27.146452  62.930412
# TMA 27 R1 | 005 | Geometric Segment  19.818808  33.031347  42.940752
#
# TargetName                               PTPRJ       GPX7
# TMA 27 R1 | 001 | Geometric Segment  45.439949  42.599952
# TMA 27 R1 | 002 | Geometric Segment  56.657936  41.151554
# TMA 27 R1 | 003 | Geometric Segment  46.617636  45.961049
# TMA 27 R1 | 004 | Geometric Segment  38.251819  48.123256
# TMA 27 R1 | 005 | Geometric Segment  53.951201  45.142841
#
# [5 rows x 18670 columns]

# %%
clf = ak.StructuredDataClassifier(overwrite=True, max_trials=50)
# Feed the structured data classifier with training data.
clf.fit(df_tr, Y, epochs=200, validation_split=0.1, batch_size=8, verbose=1)
# Out:
# Trial 1 Complete [00h 15m 32s]
# val_accuracy: 0.625
#
# Best val_accuracy So Far: 0.625
# Total elapsed time: 00h 15m 32s
#
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# True              |True              |structured_data_block_1/normalize
# False             |False             |structured_data_block_1/dense_block_1/use_batchnorm
# 2                 |2                 |structured_data_block_1/dense_block_1/num_layers
# 32                |32                |structured_data_block_1/dense_block_1/units_0
# 0                 |0                 |structured_data_block_1/dense_block_1/dropout
# 32                |32                |structured_data_block_1/dense_block_1/units_1
# 0                 |0                 |classification_head_1/dropout
# adam              |adam              |optimizer
# 0.001             |0.001             |learning_rate
# Traceback (most recent call last):
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\blocks\wrapper.py", line 249, in build
#     output_node = block.build(hp, output_node)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\blocks\preprocessing.py", line 313, in build
#     return keras_layers.MultiCategoryEncoding(encoding)(input_node)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 944, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2315, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2186, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2232, in _infer_output_signature
#     outputs = call_fn(inputs, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 689, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 439, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 41, in tf__call
#     ag__.for_stmt(ag__.converted_call(ag__.ld(zip), (ag__.ld(split_inputs), ag__.ld(self).encoding_layers), None, fscope), None, loop_body, get_state_1, set_state_1, (), {'iterate_names': '(input_node, encoding_layer)'})
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 449, in for_stmt
#     _py_for_stmt(iter_, extra_test, body, None, None)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 498, in _py_for_stmt
#     body(target)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 464, in protected_body
#     original_body(protected_iter)
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 36, in loop_body
#     ag__.if_stmt(ag__.ld(encoding_layer) is None, if_body, else_body, get_state, set_state, (), 0)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 1341, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 1394, in _py_if_stmt
#     return body() if cond else orelse()
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 31, in if_body
#     imputed = ag__.converted_call(ag__.ld(tf).where, (ag__.converted_call(ag__.ld(tf).math.is_nan, (ag__.ld(number),), None, fscope), ag__.converted_call(ag__.ld(tf).zeros_like, (ag__.ld(number),), None, fscope), ag__.ld(number)), None, fscope)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 331, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 459, in _call_unconverted
#     return f(*args)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\util\dispatch.py", line 1082, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\ops\array_ops.py", line 4930, in where_v2
#     return gen_math_ops.select_v2(condition=condition, t=x, e=y, name=name)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 9411, in select_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 797, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\func_graph.py", line 694, in _create_op_internal
#     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\ops.py", line 3754, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\ops.py", line 2129, in __init__
#     self._c_op = _create_c_op(self._graph, node_def, inputs,
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\ops.py", line 1960, in _create_c_op
#     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
# KeyboardInterrupt
# Invalid model 0/5
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x00000279A4F7D700>
# Traceback (most recent call last):
#   File "C:\Users\sathy\AppData\Local\Programs\Python\Python39\lib\weakref.py", line 368, in remove
#     self = selfref()
# KeyboardInterrupt:
# Exception ignored in: <function ScopedTFGraph.__del__ at 0x000002799FA0BB80>
# Traceback (most recent call last):
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 55, in __del__
#     self.deleter(self.graph)
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\blocks\wrapper.py", line 249, in build
#     output_node = block.build(hp, output_node)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\autokeras\blocks\preprocessing.py", line 313, in build
#     return keras_layers.MultiCategoryEncoding(encoding)(input_node)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 944, in __call__
#     return self._functional_construction_call(inputs, args, kwargs,
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2315, in _functional_construction_call
#     outputs = self._keras_tensor_symbolic_call(
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2186, in _keras_tensor_symbolic_call
#     return self._infer_output_signature(inputs, args, kwargs, input_masks)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\engine\base_layer.py", line 2232, in _infer_output_signature
#     outputs = call_fn(inputs, *args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#     return fn(*args, **kwargs)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 689, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 439, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 41, in tf__call
#     ag__.for_stmt(ag__.converted_call(ag__.ld(zip), (ag__.ld(split_inputs), ag__.ld(self).encoding_layers), None, fscope), None, loop_body, get_state_1, set_state_1, (), {'iterate_names': '(input_node, encoding_layer)'})
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 449, in for_stmt
#     _py_for_stmt(iter_, extra_test, body, None, None)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 498, in _py_for_stmt
#     body(target)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 464, in protected_body
#     original_body(protected_iter)
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 36, in loop_body
#     ag__.if_stmt(ag__.ld(encoding_layer) is None, if_body, else_body, get_state, set_state, (), 0)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 1341, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py", line 1394, in _py_if_stmt
#     return body() if cond else orelse()
#   File "C:\Users\sathy\AppData\Local\Temp\__autograph_generated_filed3wfdft4.py", line 31, in if_body
#     imputed = ag__.converted_call(ag__.ld(tf).where, (ag__.converted_call(ag__.ld(tf).math.is_nan, (ag__.ld(number),), None, fscope), ag__.converted_call(ag__.ld(tf).zeros_like, (ag__.ld(number),), None, fscope), ag__.ld(number)), None, fscope)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 331, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 459, in _call_unconverted
#     return f(*args)
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 5040, in is_nan
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
# KeyboardInterrupt
# Invalid model 1/5
# Exception ignored in: <function ScopedTFGraph.__del__ at 0x000002799FA0BB80>
# Traceback (most recent call last):
#   File "C:\Users\sathy\OneDrive\Documents\GitHub\Glioblastoma_analysis\venv\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 55, in __del__
#     self.deleter(self.graph)
# KeyboardInterrupt:
